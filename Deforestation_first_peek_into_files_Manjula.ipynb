# %%
import pandas as pd

# %%
ls
# Out:
# Annual_Deforesation/
# API_AG.LND.IRIG.AG.ZS_DS2_en_excel_v2_10518814.xls
# Droughts_ floods_extreme_temperatures/
# FAOSTAT_temp_change_data/
# Forest_Area/
# forest-area-as-share-of-land-area_ourworldindata_ByCountry.csv
# forest-area-km_ourworldindata.csv
# Forest_Area_Sq_Km/
# natural-disasters-by-type.csv
# PM25-air-pollution_ourworldindata.csv
# Population_density/
# SYB60_T25_Carbon Dioxide Emission Estimates.csv
# SYB61_T25_Threatened Species.csv
# Terrestial_protected_land/
# Untitled.ipynb

# %%
df = pd.read_csv("forest-area-km_ourworldindata.csv")

# %%
df.shape
# Out:
# (6661, 4)

# %%
df.isna().sum()
# Out:
# Entity                            0
# Code                           1196
# Year                              0
# Forest area (sq. km) (km² )       0
# dtype: int64

# %%
df.head(40)
# Out:
#          Entity Code  Year  Forest area (sq. km) (km² )
# 0   Afghanistan  AFG  1990                      13500.0
# 1   Afghanistan  AFG  1991                      13500.0
# 2   Afghanistan  AFG  1992                      13500.0
# 3   Afghanistan  AFG  1993                      13500.0
# 4   Afghanistan  AFG  1994                      13500.0
# 5   Afghanistan  AFG  1995                      13500.0
# 6   Afghanistan  AFG  1996                      13500.0
# 7   Afghanistan  AFG  1997                      13500.0
# 8   Afghanistan  AFG  1998                      13500.0
# 9   Afghanistan  AFG  1999                      13500.0
# 10  Afghanistan  AFG  2000                      13500.0
# 11  Afghanistan  AFG  2001                      13500.0
# 12  Afghanistan  AFG  2002                      13500.0
# 13  Afghanistan  AFG  2003                      13500.0
# 14  Afghanistan  AFG  2004                      13500.0
# 15  Afghanistan  AFG  2005                      13500.0
# ...

# %%
df1 = pd.read_csv("/home/mishraka/Documents/Manjula/Lambda_School/Deforestaion_Project/FAOSTAT_temp_change_data/Environment_Temperature_change_E_All_Data.csv", encoding = "ISO-8859-1")

# %%
df1.shape
# Out:
# (9248, 123)

# %%
df1.columns
# Out:
# Index(['Area Code', 'Area', 'Months Code', 'Months', 'Element Code', 'Element',
#        'Unit', 'Y1961', 'Y1961F', 'Y1962',
#        ...
#        'Y2014', 'Y2014F', 'Y2015', 'Y2015F', 'Y2016', 'Y2016F', 'Y2017',
#        'Y2017F', 'Y2018', 'Y2018F'],
#       dtype='object', length=123)

# %%
df1.head(100)
# Out:
#     Area Code         Area  Months Code       Months  Element Code  \
# 0           2  Afghanistan         7001      January          7271
# 1           2  Afghanistan         7001      January          6078
# 2           2  Afghanistan         7002     February          7271
# 3           2  Afghanistan         7002     February          6078
# 4           2  Afghanistan         7003        March          7271
# 5           2  Afghanistan         7003        March          6078
# 6           2  Afghanistan         7004        April          7271
# 7           2  Afghanistan         7004        April          6078
# 8           2  Afghanistan         7005          May          7271
# 9           2  Afghanistan         7005          May          6078
# 10          2  Afghanistan         7006         June          7271
# 11          2  Afghanistan         7006         June          6078
# 12          2  Afghanistan         7007         July          7271
# ...

# %%
df2 = pd.read_csv("/home/mishraka/Documents/Manjula/Lambda_School/Deforestaion_Project/FAOSTAT_temp_change_data/Environment_Temperature_change_E_All_Data_NOFLAG.csv", encoding = "ISO-8859-1")

# %%
df2.head()
# Out:
#    Area Code         Area  Months Code    Months  Element Code  \
# 0          2  Afghanistan         7001   January          7271
# 1          2  Afghanistan         7001   January          6078
# 2          2  Afghanistan         7002  February          7271
# 3          2  Afghanistan         7002  February          6078
# 4          2  Afghanistan         7003     March          7271
#
#               Element Unit  Y1961  Y1962  Y1963  ...  Y2009  Y2010  Y2011  \
# 0  Temperature change   °C  0.993  0.137  2.441  ...  1.764  3.677  1.096
# 1  Standard Deviation   °C  1.888  1.888  1.888  ...  1.888  1.888  1.888
# 2  Temperature change   °C -1.542  2.421  3.849  ...  3.025  0.857  1.112
# 3  Standard Deviation   °C  2.456  2.456  2.456  ...  2.456  2.456  2.456
# 4  Temperature change   °C  0.536  1.444  0.327  ...  2.543  4.204  1.837
#
#    Y2012  Y2013  Y2014  Y2015  Y2016  Y2017  Y2018
# 0 -0.304  2.136  2.422  2.278  3.621  0.279  2.700
# ...

# %%
df2.shape
# Out:
# (9248, 65)

# %%
df2.columns
# Out:
# Index(['Area Code', 'Area', 'Months Code', 'Months', 'Element Code', 'Element',
#        'Unit', 'Y1961', 'Y1962', 'Y1963', 'Y1964', 'Y1965', 'Y1966', 'Y1967',
#        'Y1968', 'Y1969', 'Y1970', 'Y1971', 'Y1972', 'Y1973', 'Y1974', 'Y1975',
#        'Y1976', 'Y1977', 'Y1978', 'Y1979', 'Y1980', 'Y1981', 'Y1982', 'Y1983',
#        'Y1984', 'Y1985', 'Y1986', 'Y1987', 'Y1988', 'Y1989', 'Y1990', 'Y1991',
#        'Y1992', 'Y1993', 'Y1994', 'Y1995', 'Y1996', 'Y1997', 'Y1998', 'Y1999',
#        'Y2000', 'Y2001', 'Y2002', 'Y2003', 'Y2004', 'Y2005', 'Y2006', 'Y2007',
#        'Y2008', 'Y2009', 'Y2010', 'Y2011', 'Y2012', 'Y2013', 'Y2014', 'Y2015',
#        'Y2016', 'Y2017', 'Y2018'],
#       dtype='object')

# %%
df3 = pd.read_csv("/home/mishraka/Documents/Manjula/Lambda_School/Deforestaion_Project/SYB60_T25_Carbon Dioxide Emission Estimates.csv", encoding = "ISO-8859-1")

# %%
df3.head(100)
# Out:
#                     T25         CO2 emission estimates Unnamed: 2  \
# 0   Region/Country/Area                            NaN       Year
# 1                     1  Total, all countries or areas       1975
# 2                     1  Total, all countries or areas       1985
# 3                     1  Total, all countries or areas       1995
# 4                     1  Total, all countries or areas       2005
# 5                     1  Total, all countries or areas       2010
# 6                     1  Total, all countries or areas       2012
# 7                     1  Total, all countries or areas       2013
# 8                     1  Total, all countries or areas       2014
# 9                     1  Total, all countries or areas       1975
# 10                    1  Total, all countries or areas       1985
# 11                    1  Total, all countries or areas       1995
# 12                    1  Total, all countries or areas       2005
# ...

# %%
df4 = pd.read_csv("/home/mishraka/Documents/Manjula/Lambda_School/Deforestaion_Project/PM25-air-pollution_ourworldindata.csv", encoding = "ISO-8859-1")

# %%
df4.head(100)
# Out:
#                  Entity Code  Year  \
# 0           Afghanistan  AFG  1990
# 1           Afghanistan  AFG  1995
# 2           Afghanistan  AFG  2000
# 3           Afghanistan  AFG  2005
# 4           Afghanistan  AFG  2010
# 5           Afghanistan  AFG  2011
# 6           Afghanistan  AFG  2012
# 7           Afghanistan  AFG  2013
# 8           Afghanistan  AFG  2014
# 9           Afghanistan  AFG  2015
# 10          Afghanistan  AFG  2016
# 11              Albania  ALB  1990
# 12              Albania  ALB  1995
# 13              Albania  ALB  2000
# 14              Albania  ALB  2005
# 15              Albania  ALB  2010
# 16              Albania  ALB  2011
# 17              Albania  ALB  2012
# 18              Albania  ALB  2013
# 19              Albania  ALB  2014
# 20              Albania  ALB  2015
# 21              Albania  ALB  2016
# 22              Algeria  DZA  1990
# 23              Algeria  DZA  1995
# 24              Algeria  DZA  2000
# ...

# %%
df5 = pd.read_csv("/home/mishraka/Documents/Manjula/Lambda_School/Deforestaion_Project/natural-disasters-by-type.csv", encoding = "ISO-8859-1")

# %%
df5.head(100)
# Out:
#                    Entity  Code  Year  \
# 0   All natural disasters   NaN  1900
# 1   All natural disasters   NaN  1901
# 2   All natural disasters   NaN  1902
# 3   All natural disasters   NaN  1903
# 4   All natural disasters   NaN  1904
# 5   All natural disasters   NaN  1905
# 6   All natural disasters   NaN  1906
# 7   All natural disasters   NaN  1907
# 8   All natural disasters   NaN  1908
# 9   All natural disasters   NaN  1909
# 10  All natural disasters   NaN  1910
# 11  All natural disasters   NaN  1911
# 12  All natural disasters   NaN  1912
# 13  All natural disasters   NaN  1913
# 14  All natural disasters   NaN  1914
# 15  All natural disasters   NaN  1915
# 16  All natural disasters   NaN  1916
# 17  All natural disasters   NaN  1917
# 18  All natural disasters   NaN  1918
# 19  All natural disasters   NaN  1919
# 20  All natural disasters   NaN  1920
# 21  All natural disasters   NaN  1921
# 22  All natural disasters   NaN  1922
# ...

# %%
df6 = pd.read_csv("/home/mishraka/Documents/Manjula/Lambda_School/Deforestaion_Project/forest-area-as-share-of-land-area_ourworldindata_ByCountry.csv", encoding = "ISO-8859-1")

# %%
df6.head(100)
# Out:
#             Entity Code  Year  \
# 0      Afghanistan  AFG  1990
# 1      Afghanistan  AFG  2000
# 2      Afghanistan  AFG  2005
# 3      Afghanistan  AFG  2010
# 4      Afghanistan  AFG  2015
# 5          Albania  ALB  1990
# 6          Albania  ALB  2000
# 7          Albania  ALB  2005
# 8          Albania  ALB  2010
# 9          Albania  ALB  2015
# 10         Algeria  DZA  1990
# 11         Algeria  DZA  2000
# 12         Algeria  DZA  2005
# 13         Algeria  DZA  2010
# 14         Algeria  DZA  2015
# 15  American Samoa  ASM  1990
# 16  American Samoa  ASM  2000
# 17  American Samoa  ASM  2005
# 18  American Samoa  ASM  2010
# 19  American Samoa  ASM  2015
# 20         Andorra  AND  1990
# 21         Andorra  AND  2000
# 22         Andorra  AND  2005
# 23         Andorra  AND  2010
# 24         Andorra  AND  2015
# 25          Angola  AGO  1990
# 26          Angola  AGO  2000
# 27          Angola  AGO  2005
# 28          Angola  AGO  2010
# 29          Angola  AGO  2015
# ...

# %%
df7 = pd.read_csv("/home/mishraka/Documents/Manjula/Lambda_School/Deforestaion_Project/land-use-over-the-long-term.csv", encoding = "ISO-8859-1")

# %%
df7.head(200)
# Out:
#      Entity Code   Year  Built-up Area (hectares)  Grazing (hectares)  \
# 0    Africa  NaN -10000                         1        0.000000e+00
# 1    Africa  NaN  -9000                         2        0.000000e+00
# 2    Africa  NaN  -8000                         4        0.000000e+00
# 3    Africa  NaN  -7000                         7        0.000000e+00
# 4    Africa  NaN  -6000                        14        0.000000e+00
# 5    Africa  NaN  -5000                        30        5.845343e+06
# 6    Africa  NaN  -4000                       107        1.120671e+07
# 7    Africa  NaN  -3000                       361        1.939875e+07
# 8    Africa  NaN  -2000                       621        3.322474e+07
# 9    Africa  NaN  -1000                       977        5.842015e+07
# 10   Africa  NaN      0                      2033        9.043100e+07
# 11   Africa  NaN    100                      2409        9.646864e+07
# ...
